# %% [markdown]
# <a href="https://colab.research.google.com/github/jmijares4/DS-portfolio/blob/main/AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from tensorflow import keras

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
farenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %% [markdown]
# ## Import dataframe so the AI can work with and learn.

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %% [markdown]
# ## Since is a farly simple model, we are using just 1 layer.

# %%
modelo.compile(
    optimizer=tf.keras.optimizers.Adam(0.1),
    loss='mean_squared_error'
)

# %% [markdown]
# ## The smaller the Adam, the better loss, but at the cost of more epochs needed.
#
# ## It´s better to have many epochs with minimal loss, than few epochs with big loss.

# %%
historial = modelo.fit(celsius, farenheit, epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 1s/step - loss: 3192.6172
# Epoch 2/1000
# 1/1 [==============================] - 0s 20ms/step - loss: 2967.7898
# Epoch 3/1000
# 1/1 [==============================] - 0s 24ms/step - loss: 2754.7051
# Epoch 4/1000
# 1/1 [==============================] - 0s 27ms/step - loss: 2553.5435
# Epoch 5/1000
# 1/1 [==============================] - 0s 18ms/step - loss: 2364.4536
# Epoch 6/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 2187.5369
# Epoch 7/1000
# 1/1 [==============================] - 0s 25ms/step - loss: 2022.8478
# Epoch 8/1000
# 1/1 [==============================] - 0s 26ms/step - loss: 1870.3914
# Epoch 9/1000
# 1/1 [==============================] - 0s 23ms/step - loss: 1730.1133
# Epoch 10/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1601.8988
# Epoch 11/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1485.5676
# Epoch 12/1000
# ...

# %%
import matplotlib.pyplot as plt
plt.xlabel("# Epoch")
plt.ylabel("Loss Magnitude")
plt.plot(historial.history["loss"])

# %% [markdown]
# ## Looking at the "Loss plot" it can be seen that  the loss was near zero at the 600´s epochs, but after a visual inspection it can be seen that the model is capable of a loss below 0.1, wich is reached after near 900 epochs, so for this spescific case 1000 epochs was a good choice for a high prescition need.

# %%
temperatura = 100.0
resultado = modelo.predict([temperatura])
print(str(temperatura) + "celsius degrees are the same as " + str(resultado) + " farenheit degrees")
# Out:
# 1/1 [==============================] - 0s 39ms/step
# 100.0celsius degrees are the same as [[211.74065]] farenheit degrees

# %% [markdown]
# ## Correct answer is 212 vs the result of 211.74065, so the model is successfully trained.

# %%
print(capa.get_weights())
# Out:
# [array([[1.7983896]], dtype=float32), array([31.901688], dtype=float32)]

# %% [markdown]
# ## The "correct" formula would be farenheit = (celsius*1.8)+32, so having as a result farenheit = (celsius*1.798)+31.90, could be considered a good result given a situation where the formula for the unit conversion is unknown.
