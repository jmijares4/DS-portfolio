# %% [markdown]
# <a href="https://colab.research.google.com/github/jmijares4/DS-portfolio/blob/main/CO2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('/content/drive/MyDrive/DATABASES/CO2 Emissions.csv')

# %% [markdown]
# In this case we import a database from a Google Drive account, so the database can be updated in case it´s needed.

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# After reviewing the data, there is a column that had the wrong datatype in the case we needed to make an analysis, so we convert the CO2_Emissions_g/km to a float data type to be able to plot the data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Make                                7385 non-null   object
#  1   Model                               7385 non-null   object
#  2   Vehicle Class                       7385 non-null   object
#  3   Engine Size(L)                      7385 non-null   float64
#  4   Cylinders                           7385 non-null   int64
#  5   Transmission                        7385 non-null   object
#  6   Fuel Type                           7385 non-null   object
#  7   Fuel Consumption City (L/100 km)    7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)     7385 non-null   float64
#  9   Fuel_Consumption_Comb_L_per_100_km  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)         7385 non-null   int64
# ...

# %%
sns.regplot(x='Fuel_Consumption_Comb_L_per_100_km', y='CO2_Emissions_g_per_km', data=data)
# Out:
# <Axes: xlabel='Fuel_Consumption_Comb_L_per_100_km', ylabel='CO2_Emissions_g_per_km'>

# %%
lr.fit(data[['Fuel_Consumption_Comb_L_per_100_km']].values, data.CO2_Emissions_g_per_km)
# Out:
# LinearRegression()

# %%
fuel_consumption_per_100km = 35

# %%
lr.predict([[fuel_consumption_per_100km]])
# Out:
# array([696.75931797])
